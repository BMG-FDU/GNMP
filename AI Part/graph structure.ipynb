# %% [markdown]
# 看看

# %%
import torch

# %%
file_path = r'.//@graph//@STgraph//0.pt'

data = torch.load(file_path, map_location=torch.device('cpu'))

print("x:", data.x)
print("edge_index:", data.edge_index)
print("y:", data.y)
print("edge_attr:", data.edge_attr)
